# %%
import pandas as pd
import numpy as np

# %%
housing = pd.read_csv('data.csv')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CRIM        505 non-null    float64
#  1   ZN          505 non-null    float64
#  2   INDUS       505 non-null    float64
#  3   CHAS        505 non-null    int64
#  4   NOX         505 non-null    float64
#  5   RM          505 non-null    float64
#  6   AGE         505 non-null    float64
#  7   DIS         505 non-null    float64
#  8   RAD         505 non-null    int64
#  9   TAX         505 non-null    int64
#  10  PTRATIO     505 non-null    float64
#  11  B           505 non-null    float64
#  12  LSTAT       505 non-null    float64
#  13  MEDV        505 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.4 KB

# %%
housing.head()
# Out:
#    CRIM        ZN          INDUS       CHAS        NOX         RM          \
# 0     0.00632        18.0        2.31           0       0.538       6.575
# 1     0.02731         0.0        7.07           0       0.469       6.421
# 2     0.02729         0.0        7.07           0       0.469       7.185
# 3     0.03237         0.0        2.18           0       0.458       6.998
# 4     0.06905         0.0        2.18           0       0.458       7.147
#
#    AGE         DIS         RAD         TAX        PTRATIO    B          \
# 0        65.2      4.0900           1        296       15.3     396.90
# 1        78.9      4.9671           2        242       17.8     396.90
# 2        61.1      4.9671           2        242       17.8     392.83
# 3        45.8      6.0622           3        222       18.7     394.63
# 4        54.2      6.0622           3        222       18.7     396.90
#
#    LSTAT      MEDV
# 0       4.98       24.0
# 1       9.14       21.6
# ...

# %%
corr_matrix = housing.corr()

# %%
corr_matrix['MEDV'].sortvalues(asscending='false')
# Out:
#             CRIM        ZN          INDUS       CHAS        NOX         \
# CRIM          1.000000   -0.556314    0.539809         NaN    0.645534
# ZN           -0.556314    1.000000   -0.041684         NaN    0.165863
# INDUS         0.539809   -0.041684    1.000000         NaN    0.700855
# CHAS               NaN         NaN         NaN         NaN         NaN
# NOX           0.645534    0.165863    0.700855         NaN    1.000000
# RM           -0.609564   -0.008640   -0.712327         NaN   -0.794738
# AGE           0.209247    0.157605    0.368790         NaN    0.307574
# DIS          -0.760101    0.515766   -0.325182         NaN   -0.531831
# RAD           0.210150    0.280631    0.628314         NaN    0.482159
# TAX           0.497118    0.338551    0.780673         NaN    0.959590
# PTRATIO       0.802322   -0.902488    0.200710         NaN    0.239397
# B            -0.316463    0.208909   -0.209095         NaN   -0.240677
# ...

# %%
def split_test_train(data,test_ratio):
    shuffled = np.random.permutation(len(data))
    test_set_size = (len(data)*test_ratio)
    train_indices = shuffled[:test_set_size]
    test_indice s= shuffled[test_set_size:]

# %%
train_set, test_set = split_test_train(housing,0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 train_set, test_set = split_test_train(housing,0.2)
#
# Cell In[20], line 4, in split_test_train(data, test_ratio)
#       2 shuffled = np.random.permutation(len(data))
#       3 test_set_size = (len(data)*test_ratio)
# ----> 4 train_indices=shuffled[:test_set_size]
#       5 test_indices=shuffled[test_set_size:]
#       6 train_set, test_set = split_test_train(housing,0.2)
#
# TypeError: slice indices must be integers or None or have an __index__ method
